# %%
import pandas as pd
import matplotlib.pyplot as plt

#lecture  CSV
df = pd.read_csv("resultats.csv")

#affichage
display(df)

# courbes
plt.figure(figsize=(10, 5))
plt.plot(df["Tour"], df["Lapins"], label="Lapins", marker="o")
plt.plot(df["Tour"], df["Renards"], label="Renards", marker="x")
plt.xlabel("Tour")
plt.ylabel("Population")
plt.title("Évolution des Lapins et Renards")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#     Tour  Lapins  Renards
# 0      0     311       84
# 1      1     298       90
# 2      2     302       99
# 3      3     298      103
# 4      4     296      106
# 5      5     281      115
# 6      6     261      120
# 7      7     156      128
# 8      8     147      131
# 9      9     129      132
# 10    10      98      133
# 11    11      81      130
# 12    12      67      126
# 13    13      62      122
# 14    14      56       55
# 15    15      58       49
# 16    16      58       37
# 17    17      56       28
# 18    18      58       27
# 19    19      67       24

# %%
# !pip3 install pandas matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lecture du CSV
df = pd.read_csv("resultats.csv")

# Affichage du contenu
display(df)

# courbes
plt.figure(figsize=(10, 5))
plt.plot(df["Tour"], df["Lapins"], label="Lapins", marker="o")
plt.plot(df["Tour"], df["Renards"], label="Renards", marker="x")
plt.xlabel("Tour")
plt.ylabel("Population")
plt.title("Évolution des Lapins et Renards")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#     Tour  Lapins  Renards
# 0      0     311       84
# 1      1     298       90
# 2      2     302       99
# 3      3     298      103
# 4      4     296      106
# 5      5     281      115
# 6      6     261      120
# 7      7     156      128
# 8      8     147      131
# 9      9     129      132
# 10    10      98      133
# 11    11      81      130
# 12    12      67      126
# 13    13      62      122
# 14    14      56       55
# 15    15      58       49
# 16    16      58       37
# 17    17      56       28
# 18    18      58       27
# 19    19      67       24
